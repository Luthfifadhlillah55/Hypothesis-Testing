# %% [markdown]
# # Graded Challenge 3

# %% [markdown]
# ## Introduction

# %% [markdown]
# **Name : Luthfi Fadhlillah**
# <br>
# **Batch : FTDS 009**

# %% [markdown]
# Data are collected from Kickstarter Platform (https://www.kaggle.com/kemical/kickstarter-projects?select=ks-projects-201801.csv). The assignment is conducted in order to fulfill the Phase 0 project as well as Graded Challenge 3, and aims to implement the Hypothesis Testing.

# %% [markdown]
# ## Import Library
# Import the library that will be used in the assignment.

# %%
import pandas as pd
import numpy as np
import scipy

# %% [markdown]
# ## Data Loading
# Loading the dataset that has been provided.

# %%
data = pd.read_csv('ks-projects-201801.csv')
data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
len(data)
# Out:
# 378661

# %%
data.shape
# Out:
# (378661, 15)

# %% [markdown]
# The dataset consists of 378661 rows and 15 columns.

# %%
data.head() #Showing the top 5 data
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
data.tail() #Showing the bottom 5 data
# Out:
#                ID                                               name  \
# 378656  999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657  999977640                                          The Tribe
# 378658  999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659  999987933                           BioDefense Education Kit
# 378660  999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# 378656      Documentary  Film & Video      USD  2014-10-17  50000.0
# 378657   Narrative Film  Film & Video      USD  2011-07-19   1500.0
# 378658   Narrative Film  Film & Video      USD  2010-08-16  15000.0
# 378659       Technology    Technology      USD  2016-02-13  15000.0
# 378660  Performance Art           Art      USD  2011-08-16   2000.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                378661 non-null  int64
#  1   name              378657 non-null  object
#  2   category          378661 non-null  object
#  3   main_category     378661 non-null  object
#  4   currency          378661 non-null  object
#  5   deadline          378661 non-null  object
#  6   goal              378661 non-null  float64
#  7   launched          378661 non-null  object
#  8   pledged           378661 non-null  float64
#  9   state             378661 non-null  object
#  10  backers           378661 non-null  int64
#  11  country           378661 non-null  object
#  12  usd pledged       374864 non-null  float64
#  13  usd_pledged_real  378661 non-null  float64
#  14  usd_goal_real     378661 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# ...

# %% [markdown]
# Not all columns are filled with correct data, there are 2 columns (name and usd_pledged) which have null values.

# %%
data.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  3.786610e+05  3.786610e+05  3.786610e+05  378661.000000  3.748640e+05
# mean   1.074731e+09  4.908079e+04  9.682979e+03     105.617476  7.036729e+03
# std    6.190862e+08  1.183391e+06  9.563601e+04     907.185035  7.863975e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.382635e+08  2.000000e+03  3.000000e+01       2.000000  1.698000e+01
# 50%    1.075276e+09  5.200000e+03  6.200000e+02      12.000000  3.947200e+02
# 75%    1.610149e+09  1.600000e+04  4.076000e+03      56.000000  3.034090e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.786610e+05   3.786610e+05
# mean       9.058924e+03   4.545440e+04
# std        9.097334e+04   1.152950e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# ...

# %% [markdown]
# From here we can find out the Mean value of each column, but to find the Mean value will be explained below using the Numpy library.

# %% [markdown]
# ## Data Cleaning
# This section contains the data preparation process in the form of data cleaning before further data exploration is carried out. The cleaning process can be in the form of giving a new name for each column, filling in missing values, deleting unused columns, and so on.

# %% [markdown]
# ### Checking Missing Value

# %%
data.isnull().sum()
# Out:
# ID                     0
# name                   4
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3797
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64

# %% [markdown]
# There are 2 columns that have a null value, namely the 'name' column (4) and the 'usd pledged' column (3797).
# <br>
# Although in the data source it is explained that:
# 1. usd_pledged: conversion in US dollars of the pledged column (conversion done by kickstarter).
# 2. usd pledge real: conversion in US dollars of the pledged column (conversion from Fixer.io API).
# <br>
#
# But I decided not to remove the usd pledged column but instead to remove the rows that have missing values.
# Why? because if I remove the usd pledged column, then I will lose 378660 data from that column, but if I only remove rows that have missing values, I only lose 3801 data.

# %%
df = data.dropna()

# %%
df.isnull().sum()
# Out:
# ID                  0
# name                0
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd pledged         0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %% [markdown]
# After I removed the row that had the missing value, now the data is clean.

# %%
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %% [markdown]
# Now, the data set consists of 374860 rows and 15 columns.

# %% [markdown]
# ## Central Tendency
# Mean, median, and mode are three kinds of "averages". There are many "averages" in statistics, but these are, I think, the three most common.

# %% [markdown]
# ### Determine the MEAN value
# The "mean" is the "average" you're used to, where you add up all the numbers and then divide by the number of numbers.

# %%
df.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  3.748600e+05  3.748600e+05  3.748600e+05  374860.000000  3.748600e+05
# mean   1.074652e+09  4.952299e+04  9.750538e+03     106.688366  7.036802e+03
# std    6.191368e+08  1.189362e+06  9.601094e+04     911.710124  7.864016e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.380633e+08  2.000000e+03  3.100000e+01       2.000000  1.698000e+01
# 50%    1.075289e+09  5.500000e+03  6.200000e+02      12.000000  3.947650e+02
# 75%    1.610137e+09  1.650000e+04  4.080000e+03      57.000000  3.034425e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.748600e+05   3.748600e+05
# mean       9.120899e+03   4.586303e+04
# std        9.131969e+04   1.158767e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# ...

# %%
goal = df["goal"]
np.mean(goal)
# Out:
# 49522.98884108733

# %%
pledge = df["pledged"]
np.mean(pledge)
# Out:
# 9750.53830083231

# %%
backer = df["backers"]
np.mean(backer)
# Out:
# 106.68836632342742

# %% [markdown]
# From the three MEAN examples above (goal, pledged and backers), it can be proven that finding the MEAN value using the Numpy library will be the same as df.describe()

# %% [markdown]
# ### Determine the MEDIAN value
# The "median" is the "middle" value in the list of numbers. To find the median, your numbers have to be listed in numerical order from smallest to largest, so you may have to rewrite your list before you can find the median.

# %%
usd_goal = df["usd_goal_real"]
np.median(usd_goal)
# Out:
# 5500.0

# %%
usd = df["usd_pledged_real"]
np.median(usd)
# Out:
# 624.495

# %% [markdown]
# ### Determine the MODE/MODUS value
# The "mode" is the value that occurs most often. If no number in the list is repeated, then there is no mode for the list.

# %%
maincateg = df["main_category"]
print(maincateg.mode())
# Out:
# 0    Film & Video
# Name: main_category, dtype: object

# %%
money = df["currency"]
print(money.mode())
# Out:
# 0    USD
# Name: currency, dtype: object

# %% [markdown]
# ## Measures of Variability
# In research, the variability of a data set helps researchers understand how much the data spreads out around the data set's midpoint, and it also helps researchers compare different sets of data. Explore measures of variability, including range, variance, and standard deviation.

# %% [markdown]
# ### Determine the Range
# Range: defined as a single number representing the spread of the data

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
df1 = pd.DataFrame({'main_category' : ['Technology', 'Music', 'Design', 'Film & Video', 'Comics', 'Art', 'Fashion'],
                   'goal' : [1000,2000,3000,6000,8000,10000,12000],
                   'backers' : [50,100,400,650,900,180,550],
                   'pledged' : [225,500,1505,5325,2030,1500,4000]})
numcols = ['goal', 'backers', 'pledged']
for col in numcols:
  print(df1[col].name + 'range: ' + str(df1[col].max() - df1[col].min()))
# Out:
# goalrange: 11000
# backersrange: 850
# pledgedrange: 5100

# %% [markdown]
# ### Determine the Variance
# Variance: defined as a number indicating how spread out the data is

# %%
df1 = pd.DataFrame({'main_category' : ['Technology', 'Music', 'Design', 'Film & Video', 'Comics', 'Art', 'Fashion'],
                   'goal' : [1000,2000,3000,6000,8000,10000,12000],
                   'backers' : [50,100,400,650,900,180,550],
                   'pledged' : [225,500,1505,5325,2030,1500,4000]})
print(df1['backers'].var())
print(df1['goal'].var())
print(df1['pledged'].var())
# Out:
# 99295.23809523809
# 17666666.666666668
# 3464000.0

# %% [markdown]
# ### Determine the Standard Deviation
# Standard deviation: defined as a number representing how far from the average each score is

# %%
df1 = pd.DataFrame({'main_category' : ['Technology', 'Music', 'Design', 'Film & Video', 'Comics', 'Art', 'Fashion'],
                   'goal' : [1000,2000,3000,6000,8000,10000,12000],
                   'backers' : [50,100,400,650,900,180,550],
                   'pledged' : [225,500,1505,5325,2030,1500,4000]})
print(df1['backers'].std())
print(df1['goal'].std())
print(df1['pledged'].std())
# Out:
# 315.1114693171896
# 4203.173404306164
# 1861.1824198610946

# %% [markdown]
# ## Confidence Interval
# a confidence interval (CI) is a range of estimates for an unknown parameter, defined as an interval with a lower bound and an upper bound (notwithstanding one-sided confidence intervals, which are bounded only on one side).

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

goal = df1['goal']
m = goal.mean() #MEAN value of the goal column.
s = goal.std()  #Standard deviation value of the goal column.
c = stats.norm.interval(0.95, m, s) #ci value

goal.plot.hist(title='Sample Distribution', bins=100, density=True) 
plt.axvline(m, color='yellow', linestyle='dashed', linewidth=2)
plt.axvline(c[0], color='green', linestyle='dashed', linewidth=2)
plt.axvline(c[1], color='green', linestyle='dashed', linewidth=2)
plt.show()

print ('MEAN of the Sample: ' + str(m))
print ('STD of the Sample: ' + str(s))
print ('Confidence Interval (95%): ' + str(c))
# Out:
# MEAN of the Sample: 6000.0
# STD of the Sample: 4203.173404306164
# Confidence Interval (95%): (-2238.0684932166932, 14238.068493216693)

# %%
backer = df1['backers']
m = backer.mean() #MEAN value of the backers column.
s = backer.std()  #STD value of the backers column.
c = stats.norm.interval(0.95, m, s) #ci value

backer.plot.hist(title='Sample Distribusi', bins=100, density=True) 
plt.axvline(m, color='yellow', linestyle='dashed', linewidth=2)
plt.axvline(c[0], color='green', linestyle='dashed', linewidth=2)
plt.axvline(c[1], color='green', linestyle='dashed', linewidth=2)
plt.show()

print ('MEAN of the Sample: ' + str(m))
print ('STD of the Sample: ' + str(s))
print ('Confidence Interval (95%): ' + str(c))
# Out:
# MEAN of the Sample: 404.2857142857143
# STD of the Sample: 315.1114693171896
# Confidence Interval (95%): (-213.32141669147558, 1021.8928452629041)

# %% [markdown]
# ## Hypothesis Testing
# Hypothesis testing is an act in statistics whereby an analyst tests an assumption regarding a population parameter. The methodology employed by the analyst depends on the nature of the data used and the reason for the analysis.
# <br>
#
# Null hypothesis (H0): A hypothesis associated with a theory one would like to prove.
# <br>
# Alternative hypothesis (H1): A hypothesis associated with a contradiction to a theory one would like to prove.
# <br>
# Critical value: The threshold value of the test statistic for rejecting the null hypothesis

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
GB_pledged_real = df[df['country']=='GB'][['usd_pledged_real','pledged']].groupby('pledged').sum()
US_pledged_real = df[df['country']=='US'][['usd_pledged_real','pledged']].groupby('pledged').sum()

print('Average usd_pledged_real of GB: ${}'.format(np.round(GB_pledged_real.usd_pledged_real.mean())))
print('Average usd_pledged_real of US : ${}'.format(np.round(US_pledged_real.usd_pledged_real.mean())))
# Out:
# Average usd_pledged_real of GB: $25070.0
# Average usd_pledged_real of US : $53235.0

# %% [markdown]
# The hypothesis on this case:
#
# **H0: μ_GB = μ_US**
#
# **H1: μ_GB != μ_US**

# %%
t_stat, p_val = stats.ttest_ind(GB_pledged_real,US_pledged_real)
print('P-value:',p_val[0]) #the p-value isn't divided by 2 since the output is two-sided p-value
print('t-statistics:',t_stat[0])
# Out:
# P-value: 1.1590564194839695e-31
# t-statistics: -11.714516874678969

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Hypothesis testing with the main object usd pledge real and seeing the values for US and GB where two sample tests were conducted. This results in a p-value of 1.1590564194839695e-31 where the standard limit for accepting H0 is 0.05 so that H0 is rejected and H1 is accepted.
# <br>
#
# A significant difference can be seen from the average for usd_pledged_real from GB and US, which is equal to:
# 1. Average usd_pledged_real of GB: $25070.0
# 2. Average usd_pledged_real of US : $53235.0
#
# Then the average is strengthened by the P-Value value < 0.05 which causes H0 can be rejected.
# Therefore, it can be concluded that usd_pledged_real for Great Britain (GB) and United State (US) are not the same/different.
